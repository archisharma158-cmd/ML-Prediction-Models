# %% [markdown]
# 1. IMPORTING IMPORTANT LIBRARIES AND UPLOADING DATASET

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\DELL\Documents\GitHub\ML-Prediction-Models\Prediction_Model_01_Heart_Disease\Data\heart_disease.csv')

# %% [markdown]
# 2. CHECKING WHEHATHER DATASET IS BALANCED AND USEABLE

# %%
print(df.head())
# Out:
#     Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 0  56.0    Male           153.0              155.0            High     Yes
# 1  69.0  Female           146.0              286.0            High      No
# 2  46.0    Male           126.0              216.0             Low      No
# 3  32.0  Female           122.0              293.0            High     Yes
# 4  60.0    Male           166.0              242.0             Low     Yes
#
#   Family Heart Disease Diabetes        BMI High Blood Pressure  ...  \
# 0                  Yes       No  24.991591                 Yes  ...
# 1                  Yes      Yes  25.221799                  No  ...
# 2                   No       No  29.855447                  No  ...
# 3                  Yes       No  24.130477                 Yes  ...
# 4                  Yes      Yes  20.486289                 Yes  ...
#
#   High LDL Cholesterol Alcohol Consumption Stress Level Sleep Hours  \
# ...

# %%
print(df.shape)
# Out:
# (10000, 21)

# %%
print(df.isnull().sum())
# Out:
# Age                       29
# Gender                    19
# Blood Pressure            19
# Cholesterol Level         30
# Exercise Habits           25
# Smoking                   25
# Family Heart Disease      21
# Diabetes                  30
# BMI                       22
# High Blood Pressure       26
# Low HDL Cholesterol       25
# High LDL Cholesterol      26
# Alcohol Consumption     2586
# Stress Level              22
# Sleep Hours               25
# Sugar Consumption         30
# Triglyceride Level        26
# Fasting Blood Sugar       22
# CRP Level                 26
# Homocysteine Level        20
# Heart Disease Status       0
# dtype: int64

# %%
df['Heart Disease Status'].value_counts().plot(kind='bar', color=['salmon', 'lightblue'])
# Out:
# <Axes: xlabel='Heart Disease Status'>

# %%
df['Heart Disease Status'].value_counts(normalize=True)*100
# Out:
# Heart Disease Status
# No     80.0
# Yes    20.0
# Name: proportion, dtype: float64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   9971 non-null   float64
#  1   Gender                9981 non-null   object
#  2   Blood Pressure        9981 non-null   float64
#  3   Cholesterol Level     9970 non-null   float64
#  4   Exercise Habits       9975 non-null   object
#  5   Smoking               9975 non-null   object
#  6   Family Heart Disease  9979 non-null   object
#  7   Diabetes              9970 non-null   object
#  8   BMI                   9978 non-null   float64
#  9   High Blood Pressure   9974 non-null   object
#  10  Low HDL Cholesterol   9975 non-null   object
#  11  High LDL Cholesterol  9974 non-null   object
#  12  Alcohol Consumption   7414 non-null   object
#  13  Stress Level          9978 non-null   object
# ...

# %%
df=df.dropna()

# %%
print(df.shape)
# Out:
# (7067, 21)

# %%
df['Heart Disease Status'].value_counts().plot(kind='bar', color=['salmon', 'lightblue'])
# Out:
# <Axes: xlabel='Heart Disease Status'>

# %%
df['Heart Disease Status'].value_counts(normalize=True)*100
# Out:
# Heart Disease Status
# No     79.694354
# Yes    20.305646
# Name: proportion, dtype: float64

# %%
print(df.head())
# Out:
#     Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 1  69.0  Female           146.0              286.0            High      No
# 2  46.0    Male           126.0              216.0             Low      No
# 3  32.0  Female           122.0              293.0            High     Yes
# 4  60.0    Male           166.0              242.0             Low     Yes
# 5  25.0    Male           152.0              257.0             Low     Yes
#
#   Family Heart Disease Diabetes        BMI High Blood Pressure  ...  \
# 1                  Yes      Yes  25.221799                  No  ...
# 2                   No       No  29.855447                  No  ...
# 3                  Yes       No  24.130477                 Yes  ...
# 4                  Yes      Yes  20.486289                 Yes  ...
# 5                   No       No  28.144681                  No  ...
#
#   High LDL Cholesterol Alcohol Consumption Stress Level Sleep Hours  \
# ...

# %%
print(df.tail())
# Out:
#        Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 9992  68.0  Female           169.0              291.0          Medium     Yes
# 9994  73.0  Female           144.0              191.0          Medium     Yes
# 9995  25.0  Female           136.0              243.0          Medium     Yes
# 9998  23.0    Male           142.0              299.0             Low     Yes
# 9999  38.0  Female           128.0              193.0          Medium     Yes
#
#      Family Heart Disease Diabetes        BMI High Blood Pressure  ...  \
# 9992                   No       No  22.839718                  No  ...
# 9994                  Yes      Yes  39.459620                  No  ...
# 9995                   No       No  18.788791                 Yes  ...
# 9998                   No      Yes  34.964026                 Yes  ...
# 9999                  Yes      Yes  25.111295                  No  ...
#
# ...

# %%
#percentage of missing values
df.isna().sum()/len(df)*100
# Out:
# Age                     0.0
# Gender                  0.0
# Blood Pressure          0.0
# Cholesterol Level       0.0
# Exercise Habits         0.0
# Smoking                 0.0
# Family Heart Disease    0.0
# Diabetes                0.0
# BMI                     0.0
# High Blood Pressure     0.0
# Low HDL Cholesterol     0.0
# High LDL Cholesterol    0.0
# Alcohol Consumption     0.0
# Stress Level            0.0
# Sleep Hours             0.0
# Sugar Consumption       0.0
# Triglyceride Level      0.0
# Fasting Blood Sugar     0.0
# CRP Level               0.0
# Homocysteine Level      0.0
# Heart Disease Status    0.0
# dtype: float64

# %% [markdown]
# THE DATASET IS A LITTLE UNBLALANCES AS YES IS ONLY 20 PERCENT AND NO IS 80 PERCENT MEANING THAT PEOPLE WHO DO NOT HAVE A HEART DISEASE OR MORE (80%) THAN THE PEOPLE WHO HAVE HEART DISEASE(20%)

# %% [markdown]
# 3. EDA

# %%
df.head()
# Out:
#     Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 1  69.0  Female           146.0              286.0            High      No
# 2  46.0    Male           126.0              216.0             Low      No
# 3  32.0  Female           122.0              293.0            High     Yes
# 4  60.0    Male           166.0              242.0             Low     Yes
# 5  25.0    Male           152.0              257.0             Low     Yes
#
#   Family Heart Disease Diabetes        BMI High Blood Pressure  ...  \
# 1                  Yes      Yes  25.221799                  No  ...
# 2                   No       No  29.855447                  No  ...
# 3                  Yes       No  24.130477                 Yes  ...
# 4                  Yes      Yes  20.486289                 Yes  ...
# 5                   No       No  28.144681                  No  ...
#
#   High LDL Cholesterol Alcohol Consumption Stress Level Sleep Hours  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7067 entries, 1 to 9999
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   7067 non-null   float64
#  1   Gender                7067 non-null   object
#  2   Blood Pressure        7067 non-null   float64
#  3   Cholesterol Level     7067 non-null   float64
#  4   Exercise Habits       7067 non-null   object
#  5   Smoking               7067 non-null   object
#  6   Family Heart Disease  7067 non-null   object
#  7   Diabetes              7067 non-null   object
#  8   BMI                   7067 non-null   float64
#  9   High Blood Pressure   7067 non-null   object
#  10  Low HDL Cholesterol   7067 non-null   object
#  11  High LDL Cholesterol  7067 non-null   object
#  12  Alcohol Consumption   7067 non-null   object
#  13  Stress Level          7067 non-null   object
#  14  Sleep Hours           7067 non-null   float64
# ...

# %%
df.describe()
# Out:
#                Age  Blood Pressure  Cholesterol Level          BMI  \
# count  7067.000000     7067.000000        7067.000000  7067.000000
# mean     49.301542      149.856092         224.722938    29.023933
# std      18.270030       17.606064          43.529500     6.276510
# min      18.000000      120.000000         150.000000    18.007058
# 25%      34.000000      134.000000         187.000000    23.633185
# 50%      49.000000      150.000000         224.000000    29.046381
# 75%      65.000000      166.000000         262.000000    34.402934
# max      80.000000      180.000000         300.000000    39.996954
#
#        Sleep Hours  Triglyceride Level  Fasting Blood Sugar    CRP Level  \
# count  7067.000000         7067.000000          7067.000000  7067.000000
# mean      6.982595          250.523136           119.966605     7.448118
# std       1.749378           87.051480            23.612628     4.358898
# ...

# %%
df.isnull().sum()
# Out:
# Age                     0
# Gender                  0
# Blood Pressure          0
# Cholesterol Level       0
# Exercise Habits         0
# Smoking                 0
# Family Heart Disease    0
# Diabetes                0
# BMI                     0
# High Blood Pressure     0
# Low HDL Cholesterol     0
# High LDL Cholesterol    0
# Alcohol Consumption     0
# Stress Level            0
# Sleep Hours             0
# Sugar Consumption       0
# Triglyceride Level      0
# Fasting Blood Sugar     0
# CRP Level               0
# Homocysteine Level      0
# Heart Disease Status    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Heart Disease Status'].value_counts()
# Out:
# Heart Disease Status
# No     5632
# Yes    1435
# Name: count, dtype: int64

# %%
df.hist(figsize=(12, 10), bins=20, layout=(3, 3))
plt.tight_layout()
plt.show()

# %%
numeric_cols = df.select_dtypes(include=np.number).columns
df[numeric_cols].boxplot(figsize=(14, 6), rot=45)
plt.title("Boxplot of Numeric Features")
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

cat_cols = df.select_dtypes(include='object').columns
n = len(cat_cols)
cols = 3
rows = (n + cols - 1) // cols
fig, axes = plt.subplots(rows, cols, figsize=(cols*5, rows*4))
axes = axes.flatten()

for ax, col in zip(axes, cat_cols):
    sns.countplot(data=df, x=col, ax=ax, palette='Set2')
    ax.set_title(col)
    ax.tick_params(axis='x', rotation=45)

for ax in axes[n:]:
    fig.delaxes(ax)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2680\2025417828.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, ax=ax, palette='Set2')
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2680\2025417828.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, ax=ax, palette='Set2')
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2680\2025417828.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, ax=ax, palette='Set2')
# ...

# %%
sns.barplot(data=df, x='Heart Disease Status', y='Age', palette='Set2')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2680\2267025997.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='Heart Disease Status', y='Age', palette='Set2')
# <Axes: xlabel='Heart Disease Status', ylabel='Age'>

# %%
sns.barplot(data=df, x='Heart Disease Status', y='Age', palette='Set2')
plt.title('Average Age by Heart Disease Status')
plt.xlabel('Heart Disease Status')
plt.ylabel('Average Age')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2680\2030233132.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='Heart Disease Status', y='Age', palette='Set2')

# %%
corr = df.corr(numeric_only=True)
print(corr)

sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm", square=True)
plt.title("Correlation Matrix of Numeric Features")
plt.show()
# Out:
#                           Age  Blood Pressure  Cholesterol Level       BMI  \
# Age                  1.000000       -0.012478           0.015486  0.019899
# Blood Pressure      -0.012478        1.000000          -0.015947  0.002142
# Cholesterol Level    0.015486       -0.015947           1.000000  0.032988
# BMI                  0.019899        0.002142           0.032988  1.000000
# Sleep Hours          0.007324        0.000510           0.000869 -0.004871
# Triglyceride Level  -0.003861        0.005569          -0.000896  0.009191
# Fasting Blood Sugar -0.001104       -0.009468           0.007003  0.005788
# CRP Level            0.003184       -0.014311          -0.025941 -0.019908
# Homocysteine Level  -0.017151        0.003297          -0.002825 -0.000540
#
#                      Sleep Hours  Triglyceride Level  Fasting Blood Sugar  \
# Age                     0.007324           -0.003861            -0.001104
# ...

# %%
sns.boxplot(x=df['Age'])
plt.title("Boxplot of Age")
plt.xlabel("Age")
plt.show()

# %%
print("Heart Disease Status distribution (%)")
print(df['Heart Disease Status'].value_counts(normalize=True) * 100)

print("\nAverage numeric feature values by Heart Disease Status:")
group_means = df.groupby('Heart Disease Status')[numeric_cols].mean()
print(group_means.T)

print("\nNumeric feature mean differences (Yes - No):")
mean_diff = group_means.loc['Yes'] - group_means.loc['No']
print(mean_diff.abs().sort_values(ascending=False))

print("\nCategorical feature distributions by Heart Disease Status (% within status):")
for col in cat_cols.drop('Heart Disease Status'):
    print(f"\n{col}")
    print(pd.crosstab(df[col], df['Heart Disease Status'], normalize='columns').round(3) * 100)
# Out:
# Heart Disease Status distribution (%)
# Heart Disease Status
# No     79.694354
# Yes    20.305646
# Name: proportion, dtype: float64
#
# Average numeric feature values by Heart Disease Status:
# Heart Disease Status          No         Yes
# Age                    49.359020   49.075958
# Blood Pressure        150.025923  149.189547
# Cholesterol Level     224.532848  225.468990
# BMI                    28.954373   29.296939
# Sleep Hours             6.975836    7.009126
# Triglyceride Level    250.012074  252.528920
# Fasting Blood Sugar   119.949929  120.032056
# CRP Level               7.459986    7.401537
# Homocysteine Level     12.418806   12.545098
#
# Numeric feature mean differences (Yes - No):
# Triglyceride Level     2.516846
# Cholesterol Level      0.936142
# Blood Pressure         0.836376
# BMI                    0.342566
# Age                    0.283062
# Homocysteine Level     0.126292
# Fasting Blood Sugar    0.082127
# CRP Level              0.058449
# ...

# %% [markdown]
# 4. MODEL COMPARISON

# %%
#FITTING VALUES OF X LABEL AND Y LABELS
x = df.drop('Heart Disease Status', axis=1)
y=df['Heart Disease Status']

# %%
#TRAIN USING LOGISTIC REGRESSION MODEL
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42, stratify=y
)

numeric_features = X_train.select_dtypes(include=np.number).columns.tolist()
categorical_features = X_train.select_dtypes(exclude=np.number).columns.tolist()

preprocessor = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), numeric_features),
        ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_features),
    ],
    remainder="drop"
)

logreg_pipeline = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("classifier", LogisticRegression(max_iter=1000, random_state=42)),
    ]
)

logreg_pipeline.fit(X_train, y_train)

y_pred = logreg_pipeline.predict(X_test)

print("Logistic Regression accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
print("Confusion matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Logistic Regression accuracy: 0.7970297029702971
#               precision    recall  f1-score   support
#
#           No       0.80      1.00      0.89      1127
#          Yes       0.00      0.00      0.00       287
#
#     accuracy                           0.80      1414
#    macro avg       0.40      0.50      0.44      1414
# weighted avg       0.64      0.80      0.71      1414
#
# Confusion matrix:
# [[1127    0]
#  [ 287    0]]
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ...

# %%
#TRAIN USING DECISION TREE CLASSIFIER MODEL
from sklearn.tree import DecisionTreeClassifier

dt_pipeline = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("classifier", DecisionTreeClassifier(random_state=42)),
    ]
)

dt_pipeline.fit(X_train, y_train)

y_pred_dt = dt_pipeline.predict(X_test)

print("Decision Tree accuracy:", accuracy_score(y_test, y_pred_dt))
print(classification_report(y_test, y_pred_dt))
print("Confusion matrix:")
print(confusion_matrix(y_test, y_pred_dt))
# Out:
# Decision Tree accuracy: 0.6654879773691655
#               precision    recall  f1-score   support
#
#           No       0.80      0.78      0.79      1127
#          Yes       0.21      0.23      0.22       287
#
#     accuracy                           0.67      1414
#    macro avg       0.50      0.50      0.50      1414
# weighted avg       0.68      0.67      0.67      1414
#
# Confusion matrix:
# [[874 253]
#  [220  67]]

# %%
#TRAIN USING RANDOM FOREST CLASSIFIER MODEL
from sklearn.ensemble import RandomForestClassifier

rf_pipeline = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("classifier", RandomForestClassifier(random_state=42, n_estimators=100)),
    ]
)

rf_pipeline.fit(X_train, y_train)

y_pred_rf = rf_pipeline.predict(X_test)

print("Random Forest accuracy:", accuracy_score(y_test, y_pred_rf))
print(classification_report(y_test, y_pred_rf))
print("Confusion matrix:")
print(confusion_matrix(y_test, y_pred_rf))
# Out:
# Random Forest accuracy: 0.7970297029702971
#               precision    recall  f1-score   support
#
#           No       0.80      1.00      0.89      1127
#          Yes       0.00      0.00      0.00       287
#
#     accuracy                           0.80      1414
#    macro avg       0.40      0.50      0.44      1414
# weighted avg       0.64      0.80      0.71      1414
#
# Confusion matrix:
# [[1127    0]
#  [ 287    0]]
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ...

# %%
#COMPARE THE PERFORMANCE OF THE THREE MODELS
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score

y_test_bin = y_test.map({'No': 0, 'Yes': 1})

models = {
    "Logistic Regression": (y_pred, logreg_pipeline),
    "Decision Tree": (y_pred_dt, dt_pipeline),
    "Random Forest": (y_pred_rf, rf_pipeline),
}

rows = []
for name, (yhat, pipe) in models.items():
    yhat_bin = pd.Series(yhat).map({'No': 0, 'Yes': 1})
    acc = accuracy_score(y_test, yhat)
    prec = precision_score(y_test_bin, yhat_bin, zero_division=0)
    rec = recall_score(y_test_bin, yhat_bin, zero_division=0)
    f1 = f1_score(y_test_bin, yhat_bin, zero_division=0)
    try:
        proba = pipe.predict_proba(X_test)[:, 1]
        roc = roc_auc_score(y_test_bin, proba)
    except Exception:
        roc = None
    rows.append((name, acc, prec, rec, f1, roc))

comparison = pd.DataFrame(rows, columns=["Model", "Accuracy", "Precision", "Recall", "F1", "ROC_AUC"]).set_index("Model")
print(comparison)
# Out:
#                      Accuracy  Precision    Recall        F1   ROC_AUC
# Model
# Logistic Regression  0.797030   0.000000  0.000000  0.000000  0.502716
# Decision Tree        0.665488   0.209375  0.233449  0.220758  0.504480
# Random Forest        0.797030   0.000000  0.000000  0.000000  0.489907

# %%
# Display comparison table and a simple bar plot of metrics
display(comparison.round(3))

# Plot Accuracy, Precision, Recall, F1
metrics = comparison[["Accuracy", "Precision", "Recall", "F1"]]
metrics.plot(kind="bar", figsize=(8,4))
plt.title("Model Comparison")
plt.ylabel("Score")
plt.ylim(0,1)
plt.xticks(rotation=0)
plt.legend(loc="lower right")
plt.tight_layout()
plt.show()

# Show ROC AUC separately
if "ROC_AUC" in comparison.columns:
    print("\nROC_AUC:")
    display(comparison[["ROC_AUC"]].round(3))
# Out:
#                      Accuracy  Precision  Recall     F1  ROC_AUC
# Model
# Logistic Regression     0.797      0.000   0.000  0.000    0.503
# Decision Tree           0.665      0.209   0.233  0.221    0.504
# Random Forest           0.797      0.000   0.000  0.000    0.490
# ROC_AUC:
#                      ROC_AUC
# Model
# Logistic Regression    0.503
# Decision Tree          0.504
# Random Forest          0.490
